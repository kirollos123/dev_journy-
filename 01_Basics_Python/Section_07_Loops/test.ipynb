# %%
num_1 = input("eenter your number :")
num_2 = input("eenter your number :")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (3.12.3) (Python 3.12.3)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
